# %% [markdown]
# ## Overview
#
# This notebook will show you how to create and query a table or DataFrame that you uploaded to DBFS. [DBFS](https://docs.databricks.com/user-guide/dbfs-databricks-file-system.html) is a Databricks File System that allows you to store data for querying inside of Databricks. This notebook assumes that you have a file already inside of DBFS that you would like to read from.
#
# This notebook is written in **Python** so the default cell type is Python. However, you can use different languages by using the `%LANGUAGE` syntax. Python, Scala, SQL, and R are all supported.

# %%
import pyspark
sc
# Out:
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="/?o=5620561482773586#setting/sparkui/0324-030348-roe4xk1c/driver-6789954650033081820">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[8]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Databricks Shell</code></dd>
#             </dl>
#         </div>

# %%
import pandas as pd
import numpy as np

# %%
# File location and type
file_location = "/FileStore/tables/Housing-1.csv"
file_type = "csv"

# CSV options
infer_schema = "false"
first_row_is_header = "true"
delimiter = ","

# The applied options are for CSV files. For other file types, these will be ignored.
df = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location)

display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>price</th><th>bedrooms</th><th>bathrooms</th><th>sqft_living</th><th>sqft_lot</th><th>floors</th><th>waterfront</th><th>view</th><th>condition</th><th>grade</th><th>sqft_above</th><th>sqft_basement</th><th>yr_built</th><th>yr_renovated</th><th>zipcode</th><th>lat</th><th>long</th><th>sqft_living15</th><th>sqft_lot15</th></tr></thead><tbody><tr><td>432000</td><td>5</td><td>2.75</td><td>2060</td><td>329903</td><td>1.5</td><td>0</td><td>3</td><td>5</td><td>7</td><td>2060</td><td>0</td><td>1989</td><td>0</td><td>98022</td><td>47.1776</td><td>-121.944</td><td>2240</td><td>220232</td></tr><tr><td>170000</td><td>2</td><td>1</td><td>810</td><td>8424</td><td>1</td><td>0</td><td>0</td><td>4</td><td>6</td><td>810</td><td>0</td><td>1959</td><td>0</td><td>98023</td><td>47.3286</td><td>-122.346</td><td>820</td><td>8424</td></tr><tr><td>235000</td><td>3</td><td>1</td><td>960</td><td>5030</td><td>1</td><td>0</td><td>0</td><td>3</td><td>7</td><td>960</td><td>0</td><td>1955</td><td>0</td><td>98118</td><td>47.5611</td><td>-122.28</td><td>1460</td><td>5400</td></tr><tr><td>350000</td><td>2</td><td>1</td><td>830</td><td>5100</td><td>1</td><td>0</td><td>0</td><td>4</td><td>7</td><td>830</td><td>0</td><td>1942</td><td>0</td><td>98126</td><td>47.5259</td><td>-122.379</td><td>1220</td><td>5100</td></tr><tr><td>397380</td><td>2</td><td>1</td><td>1030</td><td>5072</td><td>1</td><td>0</td><td>0</td><td>3</td><td>6</td><td>1030</td><td>0</td><td>1924</td><td>1958</td><td>98115</td><td>47.6962</td><td>-122.294</td><td>1220</td><td>6781</td></tr><tr><td>766500</td><td>2</td><td>1.75</td><td>2230</td><td>6930</td><td>1</td><td>0</td><td>0</td><td>4</td><td>8</td><td>1530</td><td>700</td><td>1947</td><td>0</td><td>98105</td><td>47.6705</td><td>-122.277</td><td>1970</td><td>6930</td></tr><tr><td>215000</td><td>3</td><td>1.5</td><td>1240</td><td>9405</td><td>1</td><td>0</td><td>0</td><td>4</td><td>7</td><td>1240</td><td>0</td><td>1966</td><td>0</td><td>98042</td><td>47.3727</td><td>-122.162</td><td>2260</td><td>7611</td></tr><tr><td>596500</td><td>4</td><td>2.25</td><td>1770</td><td>8505</td><td>2</td><td>0</td><td>0</td><td>3</td><td>8</td><td>1770</td><td>0</td><td>1986</td><td>0</td><td>98052</td><td>47.6904</td><td>-122.102</td><td>1880</td><td>8939</td></tr><tr><td>368750</td><td>3</td><td>2.5</td><td>2230</td><td>5717</td><td>2</td><td>0</td><td>0</td><td>3</td><td>7</td><td>2230</td><td>0</td><td>2004</td><td>0</td><td>98058</td><td>47.4388</td><td>-122.117</td><td>2230</td><td>5194</td></tr><tr><td>580000</td><td>4</td><td>2.5</td><td>2840</td><td>6268</td><td>2</td><td>0</td><td>0</td><td>3</td><td>9</td><td>2840</td><td>0</td><td>1998</td><td>0</td><td>98028</td><td>47.7386</td><td>-122.235</td><td>2790</td><td>6526</td></tr><tr><td>402000</td><td>4</td><td>2.25</td><td>1790</td><td>7311</td><td>2</td><td>0</td><td>0</td><td>3</td><td>7</td><td>1790</td><td>0</td><td>1992</td><td>0</td><td>98056</td><td>47.5055</td><td>-122.189</td><td>1400</td><td>7203</td></tr><tr><td>360000</td><td>4</td><td>1.75</td><td>2010</td><td>12188</td><td>1</td><td>0</td><td>0</td><td>4</td><td>7</td><td>1150</td><td>860</td><td>1960</td><td>0</td><td>98059</td><td>47.5013</td><td>-122.147</td><td>1720</td><td>8475</td></tr><tr><td>442000</td><td>3</td><td>1.5</td><td>2050</td><td>6384</td><td>1</td><td>0</td><td>0</td><td>3</td><td>7</td><td>1350</td><td>700</td><td>1958</td><td>0</td><td>98126</td><td>47.5325</td><td>-122.378</td><td>1590</td><td>7214</td></tr><tr><td>478000</td><td>3</td><td>2.25</td><td>1570</td><td>9500</td><td>1</td><td>0</td><td>0</td><td>4</td><td>7</td><td>1070</td><td>500</td><td>1977</td><td>0</td><td>98033</td><td>47.6843</td><td>-122.185</td><td>2250</td><td>9583</td></tr><tr><td>550000</td><td>3</td><td>2.25</td><td>2160</td><td>37000</td><td>1.5</td><td>0</td><td>0</td><td>4</td><td>7</td><td>1760</td><td>400</td><td>1933</t ...

# %%
housing = df.select("*").toPandas()

# %%
housing.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>price</th>
#       <th>bedrooms</th>
#       <th>bathrooms</th>
#       <th>sqft_living</th>
#       <th>sqft_lot</th>
#       <th>floors</th>
#       <th>waterfront</th>
#       <th>view</th>
#       <th>condition</th>
#       <th>grade</th>
#       <th>sqft_above</th>
#       <th>sqft_basement</th>
#       <th>yr_built</th>
#       <th>yr_renovated</th>
#       <th>zipcode</th>
#       <th>lat</th>
#       <th>long</th>
#       <th>sqft_living15</th>
#       <th>sqft_lot15</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>432000</td>
#       <td>5</td>
#       <td>2.75</td>
#       <td>2060</td>
#       <td>329903</td>
#       <td>1.5</td>
#       <td>0</td>
#       <td>3</td>
#       <td>5</td>
#       <td>7</td>
#       <td>2060</td>
#       <td>0</td>
#       <td>1989</td>
#       <td>0</td>
#       <td>98022</td>
#       <td>47.1776</td>
#       <td>-121.944</td>
#       <td>2240</td>
#       <td>220232</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>170000</td>
#       <td>2</td>
#       <td>1</td>
#       <td>810</td>
#       <td>8424</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>4</td>
#       <td>6</td>
#       <td>810</td>
#       <td>0</td>
#       <td>1959</td>
#       <td>0</td>
#       <td>98023</td>
#       <td>47.3286</td>
#       <td>-122.346</td>
#       <td>820</td>
#       <td>8424</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>235000</td>
#       <td>3</td>
#       <td>1</td>
#       <td>960</td>
#       <td>5030</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>3</td>
#       <td>7</td>
#       <td>960</td>
#       <td>0</td>
#       <td>1955</td>
#       <td>0</td>
#       <td>98118</td>
#       <td>47.5611</td>
#       <td>-122.28</td>
#       <td>1460</td>
#       <td>5400</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>350000</td>
#       <td>2</td>
#       <td>1</td>
#       <td>830</td>
#       <td>5100</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>4</td>
#       <td>7</td>
#       <td>830</td>
#       <td>0</td>
#       <td>1942</td>
#       <td>0</td>
#       <td>98126</td>
#       <td>47.5259</td>
#       <td>-122.379</td>
#       <td>1220</td>
#       <td>5100</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>397380</td>
#       <td>2</td>
#       <td>1</td>
#       <td>1030</td>
#       <td>5072</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>3</td>
#       <td>6</td>
#       <td>1030</td>
#       <td>0</td>
#       <td>1924</td>
#       <td>1958</td>
#       <td>98115</td>
#       <td>47.6962</td>
#       <td>-122.294</td>
#       <td>1220</td>
#       <td>6781</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
housing.shape
# Out:
# Out[6]: (19606, 19)

# %%
housing.dtypes
# Out:
# Out[7]: price            object
# bedrooms         object
# bathrooms        object
# sqft_living      object
# sqft_lot         object
# floors           object
# waterfront       object
# view             object
# condition        object
# grade            object
# sqft_above       object
# sqft_basement    object
# yr_built         object
# yr_renovated     object
# zipcode          object
# lat              object
# long             object
# sqft_living15    object
# sqft_lot15       object
# dtype: object

# %%
housing['price']=housing['price'].astype('float')
housing['bedrooms']=housing['bedrooms'].astype('float')
housing['bathrooms']=housing['bathrooms'].astype('float')
housing['sqft_lot']=housing['sqft_lot'].astype('float')
housing['floors']=housing['floors'].astype('float')
housing['grade']=housing['grade'].astype('float')
housing['yr_built']=housing['yr_built'].astype('float')
housing['zipcode']=housing['zipcode'].astype('float')
housing['lat']=housing['lat'].astype('float')
housing['long']=housing['long'].astype('float')
housing['sqft_lot15']=housing['sqft_lot15'].astype('float')
housing['sqft_living']=housing['sqft_living'].astype('float')

# %%
housing['waterfront']=housing['waterfront'].astype('int')
housing['view']=housing['view'].astype('int')
housing['condition']=housing['condition'].astype('int')
housing['sqft_above']=housing['sqft_above'].astype('int')
housing['sqft_basement']=housing['sqft_basement'].astype('int')
housing['yr_renovated']=housing['yr_renovated'].astype('int')
housing['sqft_living15']=housing['sqft_living15'].astype('int')

# %%
housing.dtypes
# Out:
# Out[10]: price            float64
# bedrooms         float64
# bathrooms        float64
# sqft_living      float64
# sqft_lot         float64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade            float64
# sqft_above         int64
# sqft_basement      int64
# yr_built         float64
# yr_renovated       int64
# zipcode          float64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15       float64
# dtype: object

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(housing, test_size=0.3)

# %%
test.shape
# Out:
# Out[12]: (5882, 19)

# %%
train.shape
# Out:
# Out[13]: (13724, 19)

# %%
train_y = train[['price']]
test_y = test[['price']]

train_inputs = train.drop(['price'], axis=1)
test_inputs = test.drop(['price'], axis=1)

# %%
train_y.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>6565</th>
#       <td>348500.0</td>
#     </tr>
#     <tr>
#       <th>1166</th>
#       <td>420000.0</td>
#     </tr>
#     <tr>
#       <th>4779</th>
#       <td>280000.0</td>
#     </tr>
#     <tr>
#       <th>10712</th>
#       <td>353000.0</td>
#     </tr>
#     <tr>
#       <th>5475</th>
#       <td>802000.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
train_inputs.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>bedrooms</th>
#       <th>bathrooms</th>
#       <th>sqft_living</th>
#       <th>sqft_lot</th>
#       <th>floors</th>
#       <th>waterfront</th>
#       <th>view</th>
#       <th>condition</th>
#       <th>grade</th>
#       <th>sqft_above</th>
#       <th>sqft_basement</th>
#       <th>yr_built</th>
#       <th>yr_renovated</th>
#       <th>zipcode</th>
#       <th>lat</th>
#       <th>long</th>
#       <th>sqft_living15</th>
#       <th>sqft_lot15</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>6565</th>
#       <td>4.0</td>
#       <td>1.75</td>
#       <td>1870.0</td>
#       <td>7575.0</td>
#       <td>1.0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>3</td>
#       <td>7.0</td>
#       <td>1480</td>
#       <td>390</td>
#       <td>1972.0</td>
#       <td>0</td>
#       <td>98034.0</td>
#       <td>47.7205</td>
#       <td>-122.218</td>
#       <td>1670</td>
#       <td>7575.0</td>
#     </tr>
#     <tr>
#       <th>1166</th>
#       <td>2.0</td>
#       <td>2.50</td>
#       <td>1480.0</td>
#       <td>1369.0</td>
#       <td>3.0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>3</td>
#       <td>7.0</td>
#       <td>1480</td>
#       <td>0</td>
#       <td>2009.0</td>
#       <td>0</td>
#       <td>98052.0</td>
#       <td>47.6760</td>
#       <td>-122.121</td>
#       <td>1390</td>
#       <td>1337.0</td>
#     </tr>
#     <tr>
#       <th>4779</th>
#       <td>3.0</td>
#       <td>2.50</td>
#       <td>1600.0</td>
#       <td>4271.0</td>
#       <td>2.0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>3</td>
#       <td>7.0</td>
#       <td>1600</td>
#       <td>0</td>
#       <td>2000.0</td>
#       <td>0</td>
#       <td>98001.0</td>
#       <td>47.3303</td>
#       <td>-122.269</td>
#       <td>1700</td>
#       <td>4746.0</td>
#     </tr>
#     <tr>
#       <th>10712</th>
#       <td>2.0</td>
#       <td>1.00</td>
#       <td>860.0</td>
#       <td>8511.0</td>
#       <td>1.0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>3</td>
#       <td>7.0</td>
#       <td>860</td>
#       <td>0</td>
#       <td>1949.0</td>
#       <td>0</td>
#       <td>98125.0</td>
#       <td>47.7312</td>
#       <td>-122.300</td>
#       <td>1554</td>
#       <td>8499.0</td>
#     </tr>
#     <tr>
#       <th>5475</th>
#       <td>3.0</td>
#       <td>1.75</td>
#       <td>2870.0</td>
#       <td>5000.0</td>
#       <td>1.5</td>
#       <td>0</td>
#       <td>0</td>
#       <td>4</td>
#       <td>8.0</td>
#       <td>1840</td>
#       <td>1030</td>
#       <td>1907.0</td>
#       <td>0</td>
#       <td>98144.0</td>
#       <td>47.5788</td>
#       <td>-122.292</td>
#       <td>2200</td>
#       <td>5000.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
numeric_columns = train_inputs.select_dtypes(include=[np.number]).columns.to_list()

# %%
binary_columns = ['waterfront']

# %%
categorical_columns=[]

# %%
for col in binary_columns:
    numeric_columns.remove(col)

# %%
numeric_columns
# Out:
# Out[21]: ['bedrooms',
#  'bathrooms',
#  'sqft_living',
#  'sqft_lot',
#  'floors',
#  'view',
#  'condition',
#  'grade',
#  'sqft_above',
#  'sqft_basement',
#  'yr_built',
#  'yr_renovated',
#  'zipcode',
#  'lat',
#  'long',
#  'sqft_living15',
#  'sqft_lot15']

# %%
binary_columns
# Out:
# Out[22]: ['waterfront']

# %%
categorical_columns
# Out:
# Out[23]: []

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder

# %%
numeric_transformer = Pipeline(steps=[
                ('imputer', SimpleImputer(strategy='median')),
                ('scaler', StandardScaler())])

# %%
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value=0)),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

# %%
binary_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent'))])

# %%
preprocessor = ColumnTransformer([
        ('num', numeric_transformer, numeric_columns),
        ('cat', categorical_transformer, categorical_columns),
        ('binary', binary_transformer, binary_columns)],
        remainder='passthrough')

#passtrough is an optional step. You don't have to use it.

# %%
#Fit and transform the train data
train_x = preprocessor.fit_transform(train_inputs)

train_x
# Out:
# Out[29]: array([[ 0.75010911, -0.39023544, -0.07663784, ..., -0.36929065,
#         -0.18082613,  0.        ],
#        [-1.41646933,  0.68669823, -0.60894928, ..., -0.85181847,
#         -0.42399711,  0.        ],
#        [-0.33318011,  0.68669823, -0.44516114, ..., -0.31759124,
#         -0.29110678,  0.        ],
#        ...,
#        [ 1.83339833,  1.76363189,  2.13450195, ...,  1.33678988,
#          0.00726299,  0.        ],
#        [ 0.75010911,  0.68669823,  1.43840239, ...,  1.88825025,
#         -0.23836386,  0.        ],
#        [ 1.83339833,  0.68669823,  1.53394547, ...,  1.14722538,
#         -0.05409499,  0.        ]])

# %%
train_x.shape
# Out:
# Out[30]: (13724, 18)

# %%
# Transform the test data
test_x = preprocessor.transform(test_inputs)

test_x
# Out:
# Out[31]: array([[ 0.75010911,  1.404654  ,  0.07350128, ..., -0.35205751,
#         -0.26748357,  0.        ],
#        [ 0.75010911,  0.68669823,  0.60581271, ...,  0.54406559,
#         -0.15268098,  0.        ],
#        [-0.33318011,  0.68669823,  0.00525622, ..., -0.19695928,
#         -0.3006964 ,  0.        ],
#        ...,
#        [-1.41646933, -0.39023544, -1.2504528 , ..., -0.71395338,
#         -0.32018751,  0.        ],
#        [-1.41646933,  0.68669823, -0.60894928, ...,  0.42343364,
#         -0.37647781,  0.        ],
#        [ 1.83339833,  1.76363189,  1.50664744, ...,  0.23386913,
#         -0.1872582 ,  0.        ]])

# %%
test_x.shape
# Out:
# Out[32]: (5882, 18)

# %%
train_y.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>6565</th>
#       <td>348500.0</td>
#     </tr>
#     <tr>
#       <th>1166</th>
#       <td>420000.0</td>
#     </tr>
#     <tr>
#       <th>4779</th>
#       <td>280000.0</td>
#     </tr>
#     <tr>
#       <th>10712</th>
#       <td>353000.0</td>
#     </tr>
#     <tr>
#       <th>5475</th>
#       <td>802000.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
mean_value = np.mean(train_y['price'])
mean_value
# Out:
# Out[34]: 454853.90935587295

# %%
#Baseline predicting all as mean 

baseline_pred = np.repeat(mean_value, len(test_y))

baseline_pred
# Out:
# Out[35]: array([454853.90935587, 454853.90935587, 454853.90935587, ...,
#        454853.90935587, 454853.90935587, 454853.90935587])

# %%
from sklearn.metrics import mean_squared_error

# %%
baseline_mse = mean_squared_error(test_y, baseline_pred)

baseline_rmse = np.sqrt(baseline_mse)

print('Baseline RMSE: {}' .format(baseline_rmse))
# Out:
# Baseline RMSE: 180916.2161164758

# %% [markdown]
# ##SGD Model with no regularization

# %%
from sklearn.linear_model import SGDRegressor 

# eta0 = learning rate
# penalty = regularization term
# max_iter = number of passes over training data (i.e., epochs)

sgd_reg = SGDRegressor(max_iter=100, penalty=None, eta0=0.01) 

sgd_reg.fit(train_x, train_y)
# Out:
# /databricks/python/lib/python3.9/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# Out[38]: SGDRegressor(max_iter=100, penalty=None)

# %%
sgd_reg.predict(test_x)
# Out:
# Out[39]: array([553820.8188173 , 388521.90652194, 480339.2016775 , ...,
#        530052.15915649, 494624.30788117, 504191.32476048])

# %%
# Create a new DataFrame

predictions = pd.DataFrame(sgd_reg.predict(test_x), columns=['Predicted'])

predictions
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>553820.818817</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>388521.906522</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>480339.201678</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>445625.403013</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>198382.002885</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>5877</th>
#       <td>526210.175810</td>
#     </tr>
#     <tr>
#       <th>5878</th>
#       <td>539049.541571</td>
#     </tr>
#     <tr>
#       <th>5879</th>
#       <td>530052.159156</td>
#     </tr>
#     <tr>
#       <th>5880</th>
#       <td>494624.307881</td>
#     </tr>
#     <tr>
#       <th>5881</th>
#       <td>504191.324760</td>
#     </tr>
#   </tbody>
# </table>
# <p>5882 rows × 1 columns</p>
# </div>

# %%
# Add the actual to the same DataFrame

predictions['Actual'] = np.array(test_y)

predictions
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Predicted</th>
#       <th>Actual</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>553820.818817</td>
#       <td>744000.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>388521.906522</td>
#       <td>338000.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>480339.201678</td>
#       <td>425000.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>445625.403013</td>
#       <td>311300.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>198382.002885</td>
#       <td>232000.0</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>5877</th>
#       <td>526210.175810</td>
#       <td>530000.0</td>
#     </tr>
#     <tr>
#       <th>5878</th>
#       <td>539049.541571</td>
#       <td>465000.0</td>
#     </tr>
#     <tr>
#       <th>5879</th>
#       <td>530052.159156</td>
#       <td>441500.0</td>
#     </tr>
#     <tr>
#       <th>5880</th>
#       <td>494624.307881</td>
#       <td>468000.0</td>
#     </tr>
#     <tr>
#       <th>5881</th>
#       <td>504191.324760</td>
#       <td>580000.0</td>
#     </tr>
#   </tbody>
# </table>
# <p>5882 rows × 2 columns</p>
# </div>

# %%
#Train RMSE
reg_train_pred = sgd_reg.predict(train_x)

train_mse = mean_squared_error(train_y, reg_train_pred)

train_rmse = np.sqrt(train_mse)

print('Train RMSE: {}' .format(train_rmse))
# Out:
# Train RMSE: 103879.6218862399

# %%
#Test RMSE
reg_test_pred = sgd_reg.predict(test_x)

test_mse = mean_squared_error (test_y, reg_test_pred)

test_rmse = np.sqrt(test_mse)

print('Test RMSE: {}' .format(test_rmse))
# Out:
# Test RMSE: 104013.88994756

# %% [markdown]
# ## L1 Regularization in SGD

# %%
#Stochastic Gradient:
sgd_reg_L1 = SGDRegressor(max_iter=50, penalty='l1', alpha = 0.1, eta0=0.01)

sgd_reg_L1.fit(train_x, train_y)
# Out:
# /databricks/python/lib/python3.9/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# Out[44]: SGDRegressor(alpha=0.1, max_iter=50, penalty='l1')

# %%
#Train RMSE
reg_train_pred = sgd_reg_L1.predict(train_x)

train_mse = mean_squared_error(train_y, reg_train_pred)

train_rmse = np.sqrt(train_mse)

print('Train RMSE: {}' .format(train_rmse))
# Out:
# Train RMSE: 103642.56542157118

# %%
#Test RMSE
reg_test_pred = sgd_reg_L1.predict(test_x)

test_mse = mean_squared_error (test_y, reg_test_pred)

test_rmse = np.sqrt(test_mse)

print('Test RMSE: {}' .format(test_rmse))
# Out:
# Test RMSE: 103804.34291623044

# %% [markdown]
# ## Try L2 Regularization in SGD

# %%
#Stochastic Gradient:

sgd_reg_L2 = SGDRegressor(max_iter=100, penalty='l2', alpha = 0.1, eta0=0.1)

sgd_reg_L2.fit(train_x, train_y)
# Out:
# /databricks/python/lib/python3.9/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# Out[47]: SGDRegressor(alpha=0.1, eta0=0.1, max_iter=100)

# %%
#Train RMSE
reg_train_pred = sgd_reg_L2.predict(train_x)

train_mse = mean_squared_error(train_y, reg_train_pred)

train_rmse = np.sqrt(train_mse)

print('Train RMSE: {}' .format(train_rmse))
# Out:
# Train RMSE: 106951.24355698458

# %%
#Test RMSE
reg_test_pred = sgd_reg_L2.predict(test_x)

test_mse = mean_squared_error (test_y, reg_test_pred)

test_rmse = np.sqrt(test_mse)

print('Test RMSE: {}' .format(test_rmse))
# Out:
# Test RMSE: 106990.55036737332

# %%
#Deep Neural Network

# %%
from sklearn.neural_network import MLPRegressor

# %%
dnn_reg = MLPRegressor(hidden_layer_sizes=(50,50,50,50,50),
                       max_iter=1000)

dnn_reg.fit(train_x, train_y)
# Out:
# /databricks/python/lib/python3.9/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# Out[52]: MLPRegressor(hidden_layer_sizes=(50, 50, 50, 50, 50), max_iter=1000)

# %%
#Train RMSE
train_pred = dnn_reg.predict(train_x)

train_mse = mean_squared_error(train_y, train_pred)

train_rmse = np.sqrt(train_mse)

print('Train RMSE: {}' .format(train_rmse))
# Out:
# Train RMSE: 66035.57381674946

# %%
#Test RMSE
test_pred = dnn_reg.predict(test_x)

test_mse = mean_squared_error(test_y, test_pred)

test_rmse = np.sqrt(test_mse)

print('Test RMSE: {}' .format(test_rmse))
# Out:
# Test RMSE: 70845.74979326146

# %%
#Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor

tree_reg = DecisionTreeRegressor(max_depth=10) 

tree_reg.fit(train_x, train_y)
# Out:
# Out[56]: DecisionTreeRegressor(max_depth=10)

# %%
#Train RMSE
train_pred = tree_reg.predict(train_x)

train_mse = mean_squared_error(train_y, train_pred)

train_rmse = np.sqrt(train_mse)

print('Train RMSE: {}' .format(train_rmse))
# Out:
# Train RMSE: 64790.86542363965

# %%
#Test RMSE
test_pred = tree_reg.predict(test_x)

test_mse = mean_squared_error(test_y, test_pred)

test_rmse = np.sqrt(test_mse)

print('Test RMSE: {}' .format(test_rmse))
# Out:
# Test RMSE: 87068.77727047513

# %%
#random forest

# %%
from sklearn.ensemble import RandomForestRegressor 

rnd_reg = RandomForestRegressor(n_estimators=500, max_depth=10, n_jobs=-1) 

rnd_reg.fit(train_x, train_y)
# Out:
# /databricks/python_shell/dbruntime/MLWorkloadsInstrumentation/_sklearn.py:29: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   original_result = original(self, *args, **kwargs)
# Out[60]: RandomForestRegressor(max_depth=10, n_estimators=500, n_jobs=-1)

# %%
#Train RMSE
train_pred = rnd_reg.predict(train_x)

train_mse = mean_squared_error(train_y, train_pred)

train_rmse = np.sqrt(train_mse)

print('Train RMSE: {}' .format(train_rmse))
# Out:
# Train RMSE: 56769.26383416178

# %%
#Test RMSE
test_pred = rnd_reg.predict(test_x)

test_mse = mean_squared_error(test_y, test_pred)

test_rmse = np.sqrt(test_mse)

print('Test RMSE: {}' .format(test_rmse))
# Out:
# Test RMSE: 71800.02927159744

# %%
#gradient boosting

# %%
from sklearn.ensemble import GradientBoostingRegressor

gb_reg = GradientBoostingRegressor(max_depth=2, n_estimators=100, learning_rate=0.1) 

gb_reg.fit(train_x, train_y)
# Out:
# /databricks/python/lib/python3.9/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# Out[64]: GradientBoostingRegressor(max_depth=2)

# %%
#Train RMSE
train_pred = gb_reg.predict(train_x)

train_mse = mean_squared_error(train_y, train_pred)

train_rmse = np.sqrt(train_mse)

print('Train RMSE: {}' .format(train_rmse))
# Out:
# Train RMSE: 79813.54153578093

# %%
#Test RMSE
test_pred = gb_reg.predict(test_x)

test_mse = mean_squared_error(test_y, test_pred)

test_rmse = np.sqrt(test_mse)

print('Test RMSE: {}' .format(test_rmse))
# Out:
# Test RMSE: 81016.84539187315

# %%
#Extra Trees
from sklearn.ensemble import ExtraTreesRegressor
extra_reg = ExtraTreesRegressor(n_estimators=500, random_state=0)
extra_reg.fit(train_x, train_y)
# Out:
# /databricks/python_shell/dbruntime/MLWorkloadsInstrumentation/_sklearn.py:29: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   original_result = original(self, *args, **kwargs)
# Out[67]: ExtraTreesRegressor(n_estimators=500, random_state=0)

# %%
#Train RMSE
train_pred = extra_reg.predict(train_x)

train_mse = mean_squared_error(train_y, train_pred)

train_rmse = np.sqrt(train_mse)

print('Train RMSE: {}' .format(train_rmse))
# Out:
# Train RMSE: 9320.781306324247

# %%
#Test RMSE
test_pred = extra_reg.predict(test_x)

test_mse = mean_squared_error(test_y, test_pred)

test_rmse = np.sqrt(test_mse)

print('Test RMSE: {}' .format(test_rmse))
# Out:
# Test RMSE: 69508.82737181033

# %%
#Ada Boost
from sklearn.ensemble import AdaBoostRegressor
ada_reg = AdaBoostRegressor(random_state=0, n_estimators=100)
ada_reg.fit(train_x, train_y)
# Out:
# /databricks/python/lib/python3.9/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# Out[70]: AdaBoostRegressor(n_estimators=100, random_state=0)

# %%
#Train RMSE
train_pred = ada_reg.predict(train_x)

train_mse = mean_squared_error(train_y, train_pred)

train_rmse = np.sqrt(train_mse)

print('Train RMSE: {}' .format(train_rmse))
# Out:
# Train RMSE: 112036.81567459975

# %%
#Test RMSE
test_pred = ada_reg.predict(test_x)

test_mse = mean_squared_error(test_y, test_pred)

test_rmse = np.sqrt(test_mse)

print('Test RMSE: {}' .format(test_rmse))
# Out:
# Test RMSE: 113538.7673275339

# %%
#Graphs

# %%
housing['sqft_living'].plot(kind="hist")
# Out:
# Out[80]: <AxesSubplot:ylabel='Frequency'>

# %%
housing['price'].plot(kind="hist")
# Out:
# Out[79]: <AxesSubplot:ylabel='Frequency'>

# %%
import matplotlib.pyplot as plt

# %%
ax1 = housing.plot.scatter(x='price',
                       y='sqft_living',
                       c='yr_built',
                           colormap='viridis')

# %%
import seaborn as sns
sns.boxplot(data = housing, x = 'bedrooms', y = 'price')
# Out:
# Out[129]: <AxesSubplot:xlabel='bedrooms', ylabel='price'>
